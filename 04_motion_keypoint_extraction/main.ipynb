# %% [markdown]
# <a href="https://colab.research.google.com/github/chjinny/DLNY/blob/main/04_motion_keypoint_extraction/main.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 모션 키포인트 검출 AI 경진대회
# https://dacon.io/competitions/official/235701/overview/
#
# - 1.[데이터 살펴보기](##_1._데이터_살펴보기)
#   - 1.1 [Drive 연결](###_1.1_Drive_연결)
#   - 1.2 [CSV 파일 살펴보기](###_1.2_CSV_파일_살펴보기)

# %% [markdown]
# ## 1. 데이터 살펴보기

# %% [markdown]
# ### 1.1 Drive 연결

# %%
from google.colab import drive 
drive.mount('/content/gdrive/')
# Out:
# Mounted at /content/gdrive/

# %% [markdown]
# 잘 연결되었는지 데이터를 확인 해 보자

# %%
import os
for (path, dir, files) in os.walk("./gdrive/My Drive/dacon/"):
  for filename in files:
    print(path, filename)

# %% [markdown]
# ### 1.2 CSV 파일 살펴보기

# %%
import pandas as pd
train_data = pd.read_csv("./gdrive/My Drive/dacon/motion_keypoint_extraction/train_df.csv")
train_data.head(3)
# Out:
#                           image       nose_x  ...  right_instep_x  right_instep_y
# 0  001-1-1-01-Z17_A-0000001.jpg  1046.389631  ...     1063.204067      838.827465
# 1  001-1-1-01-Z17_A-0000003.jpg  1069.850679  ...     1066.376234      841.499445
# 2  001-1-1-01-Z17_A-0000005.jpg  1084.475902  ...     1066.071417      841.749554
#
# [3 rows x 49 columns]

# %% [markdown]
# ### 1.3 Image 파일 살펴보기

# %%
import matplotlib.pyplot as plt
import cv2

dir = "./gdrive/My Drive/dacon/motion_keypoint_extraction/train_imgs"
file_name = train_data["image"][0]
path = f"{dir}/{file_name}"
img = cv2.imread(path)
plt.imshow(img)

# %% [markdown]
# ### 1.4 Kepoint Drawing

# %%
keypoints = train_data.iloc[0].drop("image").to_dict()
print(keypoints)
# Out:
# {'nose_x': 1046.3896308290402, 'nose_y': 344.75788121308176, 'left_eye_x': 1041.655294358602, 'left_eye_y': 329.8202250426316, 'right_eye_x': 1059.4295072365967, 'right_eye_y': 334.4842295268827, 'left_ear_x': 1020.1177961358014, 'left_ear_y': 338.89053932552036, 'right_ear_x': 1048.0, 'right_ear_y': 343.0, 'left_shoulder_x': 992.0, 'left_shoulder_y': 394.0, 'right_shoulder_x': 1054.0, 'right_shoulder_y': 400.0, 'left_elbow_x': 956.0, 'left_elbow_y': 368.0, 'right_elbow_x': 1134.0, 'right_elbow_y': 371.0, 'left_wrist_x': 1003.497242322745, 'left_wrist_y': 327.6400850772804, 'right_wrist_x': 1078.0, 'right_wrist_y': 341.0, 'left_hip_x': 999.0, 'left_hip_y': 570.0, 'right_hip_x': 1046.0, 'right_hip_y': 573.0, 'left_knee_x': 995.0, 'left_knee_y': 695.0, 'right_knee_x': 1054.0, 'right_knee_y': 698.0, 'left_ankle_x': 983.0, 'left_ankle_y': 820.0, 'right_ankle_x': 1042.0, 'right_ankle_y': 829.0, 'neck_x': 1019.1072770641459, 'neck_y': 373.76622150257566, 'left_palm_x': 1013.1373595878405, 
# ...

# %%
for key in keypoints:
